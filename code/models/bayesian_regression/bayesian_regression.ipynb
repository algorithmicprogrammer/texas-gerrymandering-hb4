# %% [markdown]
# ## Install Needed Libraries and Filepaths

# %%
import pandas as pd
import numpy as np
import pymc as pm
import arviz as az
from texas_gerrymandering_hb4.config import FINAL_CSV

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(FINAL_CSV)

# %% [markdown]
# On page 355 of "Bayesian Data Analysis" (Third Edition), the normal linear model is introduced as $y|\beta, \sigma, X \sim N(X \beta, \sigma^2 I)$.
