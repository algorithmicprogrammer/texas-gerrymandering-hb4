# %% [markdown]
# ## Selecting Variables to Access from API
# Information on the variables that can be accessed from the 2020 Decennial Census Redistricting API PL-94-171 are available at the following link: https://api.census.gov/data/2020/dec/pl/variables.html.
#
# The variables of interest to us from this particular API pertain to racial demographics.
#
# <ul>
# <li><b>GEO_ID</b>: This variable will be used later to match with the corresponding census-block shapefile.</li>
# <li><b>P1_001N</b>: Total population (includes both voting and non-voting age population).</li>
# <li><b>P3_001N</b>: Total voting age population.</li>
# <li><b>P3_003N</b>: Total white alone voting age population.</li>
# <li><b>P3_004N</b>: Total black or African American alone voting age population.</li>
# <li><b>P3_005N</b>: Total American Indian & Alaskan Native alone voting population.</li>
# <li><b>P3_006N</b>: Total Asian alone voting age population.</li>
# <li><b>P3_007N</b>: Total Native Hawaiin or other Pacific Islander alone voting age population.</li>
# <li><b>P3_008N</b>: Total voting age population of one race not listed.</li>
# <li><b>P3_009N</b>: Total voting age population of two or more races.</li>
# <li><b>P4_002N</b>: Total Hispanic or Latino voting age population.</li>
# <li><b>P4_003N</b>: Total not Hispanic or Latino voting age population.</li>
# </ul>

# %% [markdown]
# ## Configuration

# %%
from texas_gerrymandering_hb4.config import CENSUS_API_KEY, INTERIM_DATA_DIR
import os, time, random, requests, pandas as pd
from pathlib import Path
import duckdb

API_URL = "https://api.census.gov/data/2020/dec/pl"
STATE = "48"


API_KEY = CENSUS_API_KEY

VARS = [
    "GEO_ID","P1_001N","P3_001N",
    "P3_003N","P3_004N","P3_005N","P3_006N","P3_007N","P3_008N","P3_009N",
    "P4_002N","P4_003N"
]

DB_PATH  = INTERIM_DATA_DIR/ "census_demographics.duckdb"
INTERIM_DATA_DIR.mkdir(parents=True, exist_ok=True)

con = duckdb.connect(DB_PATH.as_posix())
# Out:
# 2025-09-07 13:32:37.245 | INFO     | texas_gerrymandering_hb4.config:<module>:11 - PROJ_ROOT path is: /home/aimlexpert/Documents/GitHub/texas-gerrymandering-HB4

# %% [markdown]
# ## Create Tables

# %%
cols = ", ".join([f'{c} VARCHAR' for c in VARS] + ['state VARCHAR','county VARCHAR','tract VARCHAR','block VARCHAR'])
con.execute("CREATE TABLE IF NOT EXISTS raw_pl20_tx (" + cols + ");")


con.execute("""
CREATE TABLE IF NOT EXISTS etl_progress (
  state TEXT,
  county TEXT,
  tract TEXT,
  status TEXT,
  rows   INTEGER,
  updated_at TIMESTAMP DEFAULT now()
);
""")
con.execute("CREATE INDEX IF NOT EXISTS idx_progress ON etl_progress(state, county, tract);")

# %% [markdown]
# # Calling Census API

# %%
_last_call = [0.0]

def _throttle(min_interval=0.9):
    now = time.monotonic()
    delta = now - _last_call[0]
    if delta < min_interval:
        time.sleep(min_interval - delta)
    _last_call[0] = time.monotonic()

def census_get(params, max_retries=8, base_sleep=1.2):
    params = dict(params)
    if API_KEY:
        params["key"] = API_KEY

    last = None
    for attempt in range(1, max_retries + 1):
        _throttle(0.9 + random.random() * 0.4)
        try:
            r = requests.get(API_URL, params=params, timeout=60)
            if r.ok:
                return r.json()


            if r.status_code == 429:
                ra = r.headers.get("Retry-After")
                if ra:
                    try:
                        wait = float(ra)
                    except ValueError:
                        wait = base_sleep * (2 ** (attempt - 1))
                else:
                    wait = base_sleep * (2 ** (attempt - 1))
                wait += random.random() * 0.5  # jitter
                print(f"[census_get] 429 rate-limited. Waiting {wait:.1f}s then retrying…")
                time.sleep(wait)
                last = r
                continue


            body = r.text[:300].replace("\n", " ")
            print(f"[census_get] Attempt {attempt}: HTTP {r.status_code} — {body}")
            last = r

        except requests.exceptions.RequestException as e:
            print(f"[census_get] Attempt {attempt}: network error → {e}")
            last = e


        wait = base_sleep * (2 ** (attempt - 1)) + random.random() * 0.4
        print(f"[census_get] Backing off {wait:.1f}s…")
        time.sleep(wait)

    if hasattr(last, "raise_for_status"):
        last.raise_for_status()
    raise last

# %% [markdown]
# ## Helper Functions

# %%
def list_counties(state=STATE):
    js = census_get({"get":"NAME","for":"county:*","in":f"state:{state}"})
    return pd.DataFrame(js[1:], columns=js[0])["county"].astype(str).str.zfill(3).tolist()

def list_tracts(state=STATE, county_fips=None):
    js = census_get({"get":"NAME","for":"tract:*","in":f"state:{state} county:{str(county_fips).zfill(3)}"})
    return pd.DataFrame(js[1:], columns=js[0])["tract"].astype(str).str.zfill(6).tolist()

def fetch_blocks_tract(state, county_fips, tract, fields=VARS):
    params = {
        "get": ",".join(fields),
        "for": "block:*",
        "in": f"state:{str(state).zfill(2)} county:{str(county_fips).zfill(3)} tract:{str(tract).zfill(6)}"
    }

    for tries in range(1, 6):
        try:
            js = census_get(params)
            break
        except requests.HTTPError as e:
            if e.response is not None and e.response.status_code == 429 and tries < 5:
                wait = 5 * tries + random.random() * 2
                print(f"[fetch_blocks_tract] 429 on tract {tract}. Sleeping {wait:.1f}s and retrying ({tries}/5)…")
                time.sleep(wait)
                continue
            raise

    if not js or len(js) <= 1:
        return pd.DataFrame(columns=fields+["state","county","tract","block"])
    df = pd.DataFrame(js[1:], columns=js[0])
    for col, width in [("state",2),("county",3),("tract",6),("block",4)]:
        df[col] = df[col].astype(str).str.zfill(width)
    return df

# %% [markdown]
# # Tracking ETL Progress

# %%
def is_done(state, county, tract):
    q = con.execute(
        "SELECT 1 FROM etl_progress WHERE state=? AND county=? AND tract=? AND status='done' LIMIT 1",
        [state, county, tract]
    ).fetchone()
    return q is not None

def mark_progress(state, county, tract, status, rows=None):
    con.execute("""
        INSERT INTO etl_progress(state, county, tract, status, rows, updated_at)
        VALUES (?, ?, ?, ?, ?, now())
    """, [state, county, tract, status, rows])

counties = list_counties(STATE)
print(f"Found {len(counties)} counties")

for i, c in enumerate(counties, 1):
    tracts = list_tracts(STATE, c)
    print(f"[{i}/{len(counties)}] county {c} → {len(tracts)} tracts")
    for t in tracts:
        if is_done(STATE, c, t):
            continue
        try:
            mark_progress(STATE, c, t, "started", 0)
            df = fetch_blocks_tract(STATE, c, t, VARS)
            if not df.empty:
                con.register("tmp_df", df)
                con.execute(f"""
                    INSERT INTO raw_census_demographics
                    SELECT {", ".join(VARS)}, state, county, tract, block
                    FROM tmp_df
                """)
                con.unregister("tmp_df")
            mark_progress(STATE, c, t, "done", int(len(df)))
            if len(df):
                print(f"  tract {t}: {len(df):,} rows")
        except Exception as e:
            mark_progress(STATE, c, t, "error", 0)
            print(f"  tract {t}: ERROR → {e}")
# Out:
# Found 254 counties
# [1/254] county 001 → 12 tracts
#   tract 950100: 348 rows
#   tract 950401: 21 rows
#   tract 950402: 37 rows
#   tract 950500: 193 rows
#   tract 950600: 239 rows
#   tract 950700: 179 rows
#   tract 950800: 165 rows
#   tract 950901: 201 rows
#   tract 950902: 265 rows
#   tract 951001: 155 rows
#   tract 951002: 146 rows
#   tract 951100: 326 rows
# [2/254] county 003 → 4 tracts
#   tract 950100: 535 rows
#   tract 950200: 227 rows
#   tract 950300: 227 rows
#   tract 950400: 415 rows
# [3/254] county 005 → 21 tracts
#   tract 000102: 149 rows
#   tract 000103: 69 rows
#   tract 000104: 73 rows
#   tract 000201: 55 rows
#   tract 000202: 126 rows
#   tract 000301: 119 rows
#   tract 000302: 128 rows
#   tract 000400: 216 rows
#   tract 000500: 195 rows
#   tract 000600: 166 rows
#   tract 000700: 163 rows
#   tract 000800: 114 rows
#   tract 000902: 42 rows
#   tract 000903: 47 rows
#   tract 000904: 79 rows
#   tract 001102: 86 rows
#   tract 001001: 193 rows
#   tract 001002: 164 rows
#   tract 001101: 85 rows
#   tract 001200: 248 rows
#   tract 001300: 217 rows
# [4/254] county 007 → 11 tracts
#   tract 950101: 206 rows
#   tract 950102: 165 rows
#   tract 950103: 40 rows
#   tract 950200: 58 rows
#   tract 950301: 256 rows
#   tract 950302: 36 rows
#   tract 950400: 174 rows
#   tract 950501: 68 rows
#   tract 950502: 75 rows
#   tract 950503: 134 rows
#   tract 990000: 6 rows
# [5/254] county 009 → 3 tracts
#   tract 020100: 90 rows
#   tract 020200: 448 rows
#   tract 020300: 344 rows
# [6/254] county 011 → 1 tracts
#   tract 950100: 574 rows
# [7/254] county 013 → 13 tracts
#   tract 960101: 128 rows
#   tract 960102: 327 rows
#   tract 960203: 95 rows
#   tract 960204: 50 rows
#   tract 960205: 70 rows
#   tract 960206: 103 rows
#   tract 960300: 143 rows
#   tract 960401: 70 rows
#   tract 960403: 149 rows
#   tract 960404: 73 rows
#   tract 960500: 213 rows
#   tract 960601: 173 rows
#   tract 960602: 308 rows
# [8/254] county 015 → 8 tracts
#   tract 760100: 173 rows
#   tract 760201: 128 rows
#   tract 760202: 151 rows
#   tract 760301: 106 rows
#   tract 760302: 191 rows
#   tract 760400: 276 rows
#   tract 760501: 162 rows
#   tract 760502: 224 rows
# [9/254] county 017 → 2 tracts
#   tract 950101: 174 rows
#   tract 950102: 835 rows
# [10/254] county 019 → 7 tracts
#   tract 000101: 210 rows
#   tract 000103: 164 rows
#   tract 000104: 58 rows
#   tract 000200: 317 rows
#   tract 000301: 150 rows
#   tract 000302: 75 rows
#   tract 000400: 116 rows
# [11/254] county 021 → 21 tracts
#   tract 950101: 101 rows
#   tract 950102: 182 rows
#   tract 950201: 100 rows
#   tract 980001: 5 rows
#   tract 980100: 5 rows
#   tract 990000: 2 rows
# [32/254] county 063 → 3 tracts
#   tract 950101: 208 rows
#   tract 950102: 234 rows
#   tract 950200: 181 rows
# [33/254] county 065 → 2 tracts
#   tract 950100: 508 rows
#   tract 950200: 631 rows
# [34/254] county 067 → 9 tracts
#   tract 950101: 225 rows
#   tract 950102: 124 rows
#   tract 950200: 269 rows
#   tract 950300: 87 rows
#   tract 950400: 231 rows
#   tract 950500: 155 rows
#   tract 950601: 171 rows
#   tract 950602: 290 rows
#   tract 950700: 340 rows
# [35/254] county 069 → 3 tracts
#   tract 950100: 431 rows
#   tract 950200: 271 rows
#   tract 950300: 615 rows
# [36/254] county 071 → 8 tracts
#   tract 710100: 205 rows
#   tract 710201: 123 rows
#   tract 710202: 270 rows
#   tract 710600: 36 rows
#   tract 710300: 120 rows
#   tract 710401: 281 rows
#   tract 710500: 276 rows
#   tract 990000: 1 rows
# [37/254] county 073 → 14 tracts
#   tract 950100: 306 rows
#   tract 950201: 75 rows
#   tract 950202: 179 rows
#   tract 950301: 116 rows
#   tract 950302: 165 rows
#   tract 950400: 99 rows
#   tract 950500: 153 rows
#   tract 950600: 129 rows
#   tract 950700: 114 rows
#   tract 950801: 199 rows
#   tract 950802: 210 rows
#   tract 950900: 113 rows
#   tract 951000: 221 rows
#   tract 951100: 89 rows
# [38/254] county 075 → 2 tracts
#   tract 950100: 522 rows
#   tract 950200: 424 rows
# [39/254] county 077 → 3 tracts
#   tract 030200: 282 rows
#   tract 030301: 348 rows
#   tract 030302: 496 rows
# [40/254] county 079 → 1 tracts
#   tract 950100: 933 rows
# [41/254] county 081 → 2 tracts
#   tract 950100: 317 rows
#   tract 950200: 431 rows
# [42/254] county 083 → 3 tracts
#   tract 950300: 489 rows
#   tract 950600: 436 rows
#   tract 950700: 551 rows
# [43/254] county 085 → 220 tracts
#   tract 030101: 134 rows
#   tract 030102: 231 rows
#   tract 030201: 208 rows
#   tract 030202: 309 rows
#   tract 030204: 96 rows
#   tract 030205: 79 rows
#   tract 030206: 75 rows
#   tract 030207: 274 rows
#   tract 030301: 197 rows
#   tract 030302: 74 rows
#   tract 030303: 115 rows
#   tract 030304: 137 rows
#   tract 030306: 353 rows
#   tract 030307: 308 rows
#   tract 030403: 87 rows
#   tract 030404: 74 rows
#   tract 030405: 51 rows
#   tract 030406: 50 rows
#   tract 030407: 65 rows
#   tract 030409: 26 rows
#   tract 030410: 162 rows
#   tract 030504: 77 rows
#   tract 030505: 93 rows
#   tract 030506: 71 rows
#   tract 030507: 32 rows
#   tract 030509: 34 rows
#   tract 030510: 44 rows
#   tract 030511: 203 rows
#   tract 030512: 55 rows
#   tract 030515: 67 rows
#   tract 030516: 93 rows
#   tract 030517: 130 rows
#   tract 030518: 118 rows
#   tract 030519: 182 rows
#   tract 030520: 70 rows
#   tract 030521: 58 rows
#   tract 030524: 83 rows
#   tract 030525: 62 rows
#   tract 030529: 36 rows
#   tract 030531: 83 rows
#   tract 030532: 34 rows
#   tract 310904: 122 rows
#   tract 310905: 66 rows
# [47/254] county 093 → 5 tracts
#   tract 950101: 149 rows
#   tract 950102: 259 rows
#   tract 950200: 387 rows
#   tract 950300: 262 rows
#   tract 950400: 270 rows
# [48/254] county 095 → 1 tracts
#   tract 950300: 690 rows
# [49/254] county 097 → 9 tracts
#   tract 000100: 264 rows
#   tract 000200: 431 rows
#   tract 000400: 198 rows
#   tract 000500: 159 rows
#   tract 000600: 123 rows
#   tract 000701: 120 rows
#   tract 000702: 97 rows
#   tract 000900: 404 rows
#   tract 001100: 202 rows
# [50/254] county 099 → 19 tracts
#   tract 010101: 286 rows
#   tract 010102: 242 rows
#   tract 010201: 35 rows
#   tract 010202: 161 rows
#   tract 010300: 97 rows
#   tract 010400: 114 rows
#   tract 010501: 38 rows
#   tract 010502: 21 rows
#   tract 010503: 104 rows
#   tract 010504: 79 rows
#   tract 010601: 77 rows
#   tract 010603: 85 rows
#   tract 010604: 90 rows
#   tract 010701: 76 rows
#   tract 010702: 58 rows
#   tract 010802: 79 rows
#   tract 010803: 48 rows
#   tract 010804: 113 rows
#   tract 980000: 188 rows
# [51/254] county 101 → 1 tracts
#   tract 950100: 675 rows
# [52/254] county 103 → 1 tracts
#   tract 950100: 478 rows
# [53/254] county 105 → 1 tracts
#   tract 950100: 1,174 rows
# [54/254] county 107 → 3 tracts
#   tract 950100: 375 rows
#   tract 950200: 491 rows
#   tract 950300: 233 rows
# [55/254] county 109 → 1 tracts
#   tract 950300: 1,123 rows
# [56/254] county 111 → 2 tracts
#   tract 950100: 675 rows
#   tract 950300: 312 rows
# [57/254] county 113 → 645 tracts
#   tract 000100: 70 rows
#   tract 000201: 68 rows
#   tract 000202: 77 rows
#   tract 000300: 78 rows
#   tract 000401: 55 rows
#   tract 000405: 15 rows
#   tract 000407: 18 rows
#   tract 000408: 13 rows
#   tract 000409: 59 rows
#   tract 000410: 89 rows
#   tract 000501: 17 rows
#   tract 000502: 36 rows
#   tract 000503: 14 rows
#   tract 000605: 35 rows
#   tract 000606: 50 rows
#   tract 000607: 21 rows
#   tract 000608: 33 rows
#   tract 000609: 32 rows
#   tract 000610: 13 rows
#   tract 000611: 12 rows
#   tract 000703: 18 rows
#   tract 000704: 19 rows
#   tract 000705: 23 rows
#   tract 000706: 22 rows
#   tract 000801: 40 rows
#   tract 000802: 18 rows
#   tract 000901: 32 rows
#   tract 000902: 17 rows
#   tract 001001: 22 rows
#   tract 001002: 36 rows
#   tract 001101: 63 rows
#   tract 001102: 35 rows
#   tract 001202: 60 rows
#   tract 001203: 23 rows
#   tract 001204: 28 rows
#   tract 001301: 50 rows
#   tract 001302: 42 rows
#   tract 001400: 53 rows
#   tract 001502: 47 rows
#   tract 001503: 28 rows
#   tract 001504: 33 rows
#   tract 001601: 30 rows
#   tract 001602: 40 rows
#   tract 001703: 38 rows
#   tract 001705: 70 rows
#   tract 001801: 14 rows
#   tract 001802: 29 rows
#   tract 001901: 39 rows
#   tract 001902: 36 rows
#   tract 002001: 48 rows
#   tract 950400: 91 rows
#   tract 950500: 171 rows
# [233/254] county 465 → 14 tracts
#   tract 950202: 96 rows
#   tract 950203: 104 rows
#   tract 950301: 141 rows
#   tract 950302: 137 rows
#   tract 950400: 169 rows
#   tract 950501: 162 rows
#   tract 950502: 132 rows
#   tract 950601: 121 rows
#   tract 950602: 214 rows
#   tract 950701: 109 rows
#   tract 950702: 133 rows
#   tract 950801: 176 rows
#   tract 950802: 1,130 rows
#   tract 980000: 6 rows
# [234/254] county 467 → 14 tracts
#   tract 950100: 207 rows
#   tract 950200: 178 rows
#   tract 950300: 189 rows
#   tract 950400: 146 rows
#   tract 950500: 141 rows
#   tract 950601: 146 rows
#   tract 950602: 101 rows
#   tract 950700: 171 rows
#   tract 950801: 170 rows
#   tract 950802: 58 rows
#   tract 950901: 201 rows
#   tract 950902: 66 rows
#   tract 951001: 82 rows
#   tract 951002: 110 rows
# [235/254] county 469 → 25 tracts
#   tract 000100: 156 rows
#   tract 000201: 111 rows
#   tract 000202: 71 rows
#   tract 000301: 94 rows
#   tract 000302: 41 rows
#   tract 000400: 129 rows
#   tract 000501: 69 rows
#   tract 000502: 59 rows
#   tract 000601: 141 rows
#   tract 000602: 91 rows
#   tract 000700: 174 rows
#   tract 000800: 178 rows
#   tract 001300: 198 rows
#   tract 001401: 122 rows
#   tract 001402: 77 rows
#   tract 001501: 109 rows
#   tract 001503: 34 rows
#   tract 001504: 100 rows
#   tract 001601: 64 rows
#   tract 001604: 58 rows
#   tract 001605: 33 rows
#   tract 001607: 136 rows
#   tract 001608: 50 rows
#   tract 001700: 284 rows
#   tract 980000: 4 rows
# [236/254] county 471 → 12 tracts
#   tract 790101: 177 rows
#   tract 790102: 77 rows
#   tract 790103: 182 rows
#   tract 790200: 234 rows
#   tract 790301: 92 rows
#   tract 790302: 207 rows
#   tract 790401: 91 rows
#   tract 790402: 62 rows
#   tract 790500: 128 rows
#   tract 790600: 82 rows
#   tract 790700: 61 rows
#   tract 790800: 61 rows
# [237/254] county 473 → 11 tracts
#   tract 680100: 147 rows
#   tract 680201: 159 rows
#   tract 680202: 191 rows
#   tract 680301: 215 rows
#   tract 680302: 63 rows
#   tract 680303: 129 rows
#   tract 680501: 308 rows
#   tract 680502: 243 rows
#   tract 680601: 45 rows
#   tract 680602: 110 rows
#   tract 980000: 9 rows
# [238/254] county 475 → 3 tracts
#   tract 950100: 892 rows
#   tract 950200: 196 rows
#   tract 950300: 180 rows
# [239/254] county 477 → 9 tracts
#   tract 170100: 116 rows
#   tract 170201: 90 rows
#   tract 170202: 92 rows
#   tract 170300: 183 rows
#   tract 170400: 237 rows
#   tract 170501: 234 rows
#   tract 170502: 189 rows
#   tract 170601: 107 rows
#   tract 170602: 71 rows
# [240/254] county 479 → 69 tracts
#   tract 000101: 146 rows
#   tract 000105: 73 rows
#   tract 000106: 88 rows
#   tract 000107: 67 rows
#   tract 000108: 37 rows
#   tract 000109: 45 rows
#   tract 000200: 138 rows
#   tract 000300: 63 rows
#   tract 000601: 86 rows
#   tract 020701: 103 rows
#   tract 020704: 32 rows
#   tract 020706: 36 rows
#   tract 020707: 64 rows
#   tract 020709: 37 rows
#   tract 020710: 51 rows
#   tract 020711: 42 rows
#   tract 020712: 51 rows
#   tract 020713: 27 rows
#   tract 020808: 104 rows
#   tract 020810: 59 rows
#   tract 020811: 42 rows
#   tract 020812: 73 rows
#   tract 020813: 144 rows
#   tract 020814: 43 rows
#   tract 020815: 14 rows
#   tract 020816: 80 rows
#   tract 020817: 76 rows
#   tract 020818: 77 rows
#   tract 020819: 44 rows
#   tract 020820: 58 rows
#   tract 020821: 66 rows
#   tract 020822: 91 rows
#   tract 020900: 366 rows
#   tract 021000: 134 rows
#   tract 021100: 116 rows
#   tract 021201: 52 rows
#   tract 021202: 85 rows
#   tract 021203: 67 rows
#   tract 021300: 326 rows
#   tract 021402: 184 rows
#   tract 021404: 82 rows
#   tract 021405: 131 rows
#   tract 021406: 105 rows
#   tract 021407: 95 rows
#   tract 021502: 35 rows
#   tract 021503: 48 rows
#   tract 021506: 41 rows
#   tract 021509: 79 rows
#   tract 021510: 57 rows
#   tract 021511: 42 rows
#   tract 021512: 52 rows
#   tract 021513: 17 rows
#   tract 021514: 12 rows
#   tract 021515: 46 rows
#   tract 021516: 35 rows
#   tract 021517: 27 rows
#   tract 021518: 37 rows
#   tract 021601: 150 rows
#   tract 021602: 75 rows
#   tract 021603: 141 rows
# [247/254] county 493 → 12 tracts
#   tract 000102: 117 rows
#   tract 000103: 82 rows
#   tract 000104: 50 rows
#   tract 000201: 57 rows
#   tract 000202: 95 rows
#   tract 000300: 158 rows
#   tract 000402: 72 rows
#   tract 000404: 81 rows
#   tract 000405: 30 rows
#   tract 000406: 56 rows
#   tract 000500: 240 rows
#   tract 000600: 190 rows
# [248/254] county 495 → 3 tracts
#   tract 950200: 139 rows
#   tract 950300: 167 rows
#   tract 950400: 221 rows
# [249/254] county 497 → 16 tracts
#   tract 150101: 213 rows
#   tract 150103: 135 rows
#   tract 150104: 83 rows
#   tract 150201: 194 rows
#   tract 150202: 155 rows
#   tract 150300: 181 rows
#   tract 150402: 224 rows
#   tract 150403: 113 rows
#   tract 150404: 154 rows
#   tract 150405: 284 rows
#   tract 150500: 197 rows
#   tract 150603: 131 rows
#   tract 150604: 91 rows
#   tract 150605: 125 rows
#   tract 150606: 105 rows
#   tract 150607: 125 rows
# [250/254] county 499 → 12 tracts
#   tract 950100: 280 rows
#   tract 950200: 150 rows
#   tract 950301: 195 rows
#   tract 950303: 191 rows
#   tract 950304: 120 rows
#   tract 950401: 86 rows
#   tract 950402: 118 rows
#   tract 950500: 129 rows
#   tract 950601: 291 rows
#   tract 950602: 198 rows
#   tract 950700: 210 rows
#   tract 950800: 237 rows
# [251/254] county 501 → 2 tracts
#   tract 950100: 448 rows
#   tract 950200: 374 rows
# [252/254] county 503 → 5 tracts
#   tract 950200: 505 rows
#   tract 950401: 127 rows
#   tract 950402: 415 rows
#   tract 950500: 131 rows
#   tract 950600: 150 rows
# [253/254] county 505 → 6 tracts
#   tract 950303: 85 rows
#   tract 950304: 100 rows
#   tract 950305: 143 rows
#   tract 950306: 101 rows
#   tract 950401: 110 rows
#   tract 950402: 510 rows
# [254/254] county 507 → 4 tracts
#   tract 950100: 305 rows
#   tract 950200: 338 rows
#   tract 950301: 378 rows
#   tract 950302: 228 rows

# %% [markdown]
# ## Building a Clean Table and Exporting

# %%
VAP_RACE_VARS = ["P3_003N","P3_004N","P3_005N","P3_006N","P3_007N","P3_008N","P3_009N"]
HISP_VARS     = ["P4_002N","P4_003N"]

con.execute("DROP TABLE IF EXISTS census_demographics_clean;")

race_casts = ", ".join([f"CAST({c} AS BIGINT) AS {c}" for c in VAP_RACE_VARS])
hisp_casts = ", ".join([f"CAST({c} AS BIGINT) AS {c}" for c in HISP_VARS])

con.execute(f"""
CREATE TABLE census_demographics_clean AS
WITH base AS (
  SELECT
    state, county, tract, block, GEO_ID,
    CAST(P1_001N AS BIGINT) AS P1_001N,
    CAST(P3_001N AS BIGINT) AS P3_001N,
    {race_casts},
    {hisp_casts},
    state || county || tract || block AS GEOID20,
    REPLACE(REPLACE(GEO_ID,'15000US',''),'1000000US','') AS GEOID_from_GEO_ID
  FROM raw_census_demographics
),
shares AS (
  SELECT
    *,
    {", ".join([f"CAST({c} AS DOUBLE)/NULLIF(CAST(P3_001N AS DOUBLE),0) AS {c}_share_vap" for c in VAP_RACE_VARS + HISP_VARS])}
  FROM base
)
SELECT * FROM shares;
""")


con.execute("""
CREATE TABLE census_demographics_clean_dedup AS
SELECT * FROM (
  SELECT *, ROW_NUMBER() OVER (PARTITION BY GEOID20 ORDER BY GEO_ID) rn
  FROM pl20_tx_clean
) WHERE rn=1;
""")
con.execute("DROP TABLE census_demographics_clean;")
con.execute("ALTER TABLE census_demographics_clean_dedup RENAME TO pl20_tx_clean;")

print(con.execute("SELECT COUNT(*) rows, COUNT(DISTINCT GEOID20) uniq FROM census_demographics_clean;").fetchdf())
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[6], line 39
#       9 con.execute(f"""
#      10 CREATE TABLE pl20_tx_clean AS
#      11 WITH base AS (
#    (...)     28 SELECT * FROM shares;
#      29 """)
#      32 con.execute("""
#      33 CREATE TABLE pl20_tx_clean_dedup AS
#      34 SELECT * FROM (
#    (...)     37 ) WHERE rn=1;
#      38 """)
# ---> 39 con.execute("DROP TABLE census_demographics_clean;")
#      40 con.execute("ALTER TABLE census_demographics_clean_dedup RENAME TO pl20_tx_clean;")
#      42 print(con.execute("SELECT COUNT(*) rows, COUNT(DISTINCT GEOID20) uniq FROM census_demographics_clean;").fetchdf())
#
# CatalogException: Catalog Error: Table with name census_demographics_clean does not exist!
# Did you mean "pg_namespace"?

# %% [markdown]
# ## Exporting Parquet File

# %%
PARQUET_OUT = INTERIM_DATA_DIR / "census_demographic_blocks_clean.parquet"


con.execute(f"COPY census_demographics_clean TO '{PARQUET_OUT.as_posix()}' (FORMAT PARQUET);")
print("Saved Parquet:", PARQUET_OUT)
