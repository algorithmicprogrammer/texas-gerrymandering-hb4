# %% [markdown]
# ## Import Needed Libraries and Filepaths

# %%
import pyarrow.parquet as pq
from texas_gerrymandering_hb4.config import ELECTION_RETURNS

# %% [markdown]
# ## Read Parquet File Schema

# %%
schema = pq.read_schema(ELECTION_RETURNS)

# %% [markdown]
# Print Column Names with DataTypes

# %%
for field in schema:
    print(f"{field.name}: {field.type}")
# Out:
# election_id: large_string
# vtd_geoid: large_string
# votes_total: int64
# votes_dem: int64
# votes_rep: int64
# votes_other: int64
# dem_share: double
