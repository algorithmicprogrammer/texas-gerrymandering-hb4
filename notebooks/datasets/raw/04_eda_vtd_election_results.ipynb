# %% [markdown]
# ## Import Needed Filepaths & Libraries

# %%
from texas_gerrymandering_hb4.config import INTERIM_DATA_DIR, GEN_ELECTION_CSV
import pandas as pd

# %% [markdown]
# ## Load Raw Dataset into Pandas DataFrame

# %%
df = pd.read_csv(GEN_ELECTION_CSV)

# %% [markdown]
# ## Obtain Number of Rows and Columns

# %%
print("Shape (rows, cols):", df.shape)
# Out:
# Shape (rows, cols): (450357, 10)

# %% [markdown]
# ## List Column Names

# %%
print(list(df.columns))
# Out:
# ['County', 'FIPS', 'VTD', 'cntyvtd', 'vtdkeyvalue', 'Office', 'Name', 'Party', 'Incumbent', 'Votes']

# %% [markdown]
# ## Check for Missing Values

# %%
df.isna().sum()
# Out:
# County         0
# FIPS           0
# VTD            0
# cntyvtd        0
# vtdkeyvalue    0
# Office         0
# Name           0
# Party          0
# Incumbent      0
# Votes          0
# dtype: int64

# %% [markdown]
# ## Peek at the First 5 Rows

# %%
df.head()
# Out:
#      County  FIPS   VTD cntyvtd  vtdkeyvalue     Office    Name Party  \
# 0  Anderson     1  0001   10001            1  President  Harris     D
# 1  Anderson     1  0002   10002            2  President  Harris     D
# 2  Anderson     1  0003   10003            3  President  Harris     D
# 3  Anderson     1  0004   10004            4  President  Harris     D
# 4  Anderson     1  0005   10005            5  President  Harris     D
#
#   Incumbent  Votes
# 0         N    325
# 1         N    182
# 2         N    110
# 3         N    109
# 4         N     17
