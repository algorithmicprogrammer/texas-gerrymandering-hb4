# %%
from texas_gerrymandering_hb4.config import REP_PRIMARY_CSV
import pandas as pd


df = pd.read_csv(REP_PRIMARY_CSV)

df.info()
# Out:
# 2026-03-31 17:26:31.690 | INFO     | texas_gerrymandering_hb4.config:<module>:11 - PROJ_ROOT path is: /home/algorithmicprogrammer/Documents/texas-gerrymandering-hb4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303618 entries, 0 to 303617
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   County       303618 non-null  object
#  1   FIPS         303618 non-null  int64
#  2   VTD          303618 non-null  object
#  3   cntyvtd      303618 non-null  object
#  4   vtdkeyvalue  303618 non-null  int64
#  5   Office       303618 non-null  object
#  6   Name         303618 non-null  object
#  7   Party        303618 non-null  object
#  8   Incumbent    303618 non-null  object
#  9   Votes        303618 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 23.2+ MB
